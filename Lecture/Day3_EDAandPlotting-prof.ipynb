# %% [markdown]
# # DS3000 Day 3
#
# Sep 18/19, 2025
#
# Admin
# - Homework 2 due by **October 3rd**
#
# Push-Up Tracker
# - Section 04:
# - Section 05:
#
# Content:
# - Exploring Data
#     - Plotting
#     - (Next Time):
#       - Cleaning Data (we've already done some of this)
#       - Basic Data Summaries

# %%
# packages for today
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Extra credit 1
#
# ## Using groupby on `male_life_expectancy` column, describe it.(Hint: There is a function that can do this)

# %%
# Put your code here:

df1=df_EUpop.groupby('male_life_expectancy').describe()
df1
# Out:
#                      female_life_expectancy                               \
#                                       count  mean       std   min    25%
# male_life_expectancy
# 66.4                                    1.0  76.2       NaN  76.2  76.20
# 66.5                                    1.0  76.4       NaN  76.4  76.40
# 67.7                                    1.0  76.3       NaN  76.3  76.30
# 69.3                                    1.0  79.4       NaN  79.4  79.40
# 69.9                                    1.0  77.5       NaN  77.5  77.50
# 70.1                                    1.0  80.0       NaN  80.0  80.00
# 70.5                                    1.0  78.4       NaN  78.4  78.40
# 70.9                                    1.0  80.1       NaN  80.1  80.10
# 71.4                                    1.0  77.2       NaN  77.2  77.20
# 72.3                                    1.0  79.1       NaN  79.1  79.10
# 72.6                                    1.0  80.8       NaN  80.8  80.80
# 73.2                                    1.0  78.8       NaN  78.8  78.80
# 73.5                                    1.0  80.4       NaN  80.4  80.40
# 74.2                                    1.0  82.7       NaN  82.7  82.70
# 75.3                                    1.0  81.3       NaN  81.3  81.30
# 77.2                                    1.0  80.3       NaN  80.3  80.30
# 77.8                                    1.0  83.4       NaN  83.4  83.40
# 78.0                                    1.0  84.1       NaN  84.1  84.10
# 78.6                                    3.0  83.4  0.300000  83.1  83.25
# 78.9                                    1.0  83.6       NaN  83.6  83.60
# 79.0                                    1.0  82.9       NaN  82.9  82.90
# 79.2                                    1.0  85.3       NaN  85.3  85.30
# 79.4                                    2.0  84.6  0.565685  84.2  84.40
# 79.6                                    1.0  83.6       NaN  83.6  83.60
# 79.7                                    1.0  85.1       NaN  85.1  85.10
# 79.8                                    1.0  83.1       NaN  83.1  83.10
# 80.1                                    1.0  83.6       NaN  83.6  83.60
# 80.4                                    1.0  84.1       NaN  84.1  84.10
# 80.7                                    1.0  84.2       NaN  84.2  84.20
# 80.8                                    1.0  84.6       NaN  84.6  84.60
# 81.1                                    1.0  85.2       NaN  85.2  85.20
# 81.6                                    1.0  84.9       NaN  84.9  84.90
# 81.7                                    1.0  84.5       NaN  84.5  84.50
#
#                                         birth_rate             ...         \
#                        50%    75%   max      count       mean  ...    75%
# male_life_expectancy                                           ...
# 66.4                  76.2  76.20  76.2        1.0   7.800000  ...   7.80
# 66.5                  76.4  76.40  76.4        1.0   9.800000  ...   9.80
# 70.5                   9.2        1.0  15.40       NaN  15.4  15.400  15.40
# 70.9                   9.2        1.0  15.20       NaN  15.2  15.200  15.20
# 71.4                   8.9        1.0  16.90       NaN  16.9  16.900  16.90
# 72.3                   9.6        1.0  14.50       NaN  14.5  14.500  14.50
# 72.6                   9.4        1.0  12.60       NaN  12.6  12.600  12.60
# 73.2                  11.4        1.0  11.70       NaN  11.7  11.700  11.70
# 73.5                  10.4        1.0  10.80       NaN  10.8  10.800  10.80
# 74.2                   9.9        1.0  11.90       NaN  11.9  11.900  11.90
# 75.3                  10.3        1.0  12.10       NaN  12.1  12.100  12.10
# 77.2                  11.5        1.0   8.30       NaN   8.3   8.300   8.30
# 77.8                   8.9        1.0  11.40       NaN  11.4  11.400  11.40
# 78.0                   8.2        1.0  12.00       NaN  12.0  12.000  12.00
# 78.6                   9.9        3.0  11.70  0.624500  11.0  11.450  11.90
# 78.9                   9.4        1.0  10.30       NaN  10.3  10.300  10.30
# 79.0                  10.2        1.0  10.40       NaN  10.4  10.400  10.40
# 79.2                  10.9        1.0   9.90       NaN   9.9   9.900   9.90
# 79.4                  10.2        2.0   8.65  1.909188   7.3   7.975   8.65
# 79.6                  10.4        1.0   9.40       NaN   9.4   9.400   9.40
# 79.7                   7.1        1.0  10.40       NaN  10.4  10.400  10.40
# 79.8                   9.7        1.0   9.70       NaN   9.7   9.700   9.70
# 80.1                   9.1        1.0   8.20       NaN   8.2   8.200   8.20
# 80.4                  11.2        1.0   6.40       NaN   6.4   6.400   6.40
# 80.7                  10.9        1.0   9.50       NaN   9.5   9.500   9.50
# 80.8                   8.6        1.0   7.90       NaN   7.9   7.900   7.90
# 81.1                   9.9        1.0   8.80       NaN   8.8   8.800   8.80
# 81.6                   9.8        1.0   7.50       NaN   7.5   7.500   7.50
# 81.7                  12.3        1.0   6.30       NaN   6.3   6.300   6.30
#
#
#                          75%   max
# male_life_expectancy
# 66.4                  15.900  15.9
# 66.5                  14.600  14.6
# 67.7                  11.800  11.8
# 69.3                  13.000  13.0
# 69.9                  18.000  18.0
# 70.1                  15.600  15.6
# 70.5                  15.400  15.4
# 70.9                  15.200  15.2
# 71.4                  16.900  16.9
# 72.3                  14.500  14.5
# 72.6                  12.600  12.6
# 73.2                  11.700  11.7
# 73.5                  10.800  10.8
# 74.2                  11.900  11.9
# 75.3                  12.100  12.1
# 77.2                   8.300   8.3
# 77.8                  11.400  11.4
# 78.0                  12.000  12.0
# 78.6                  12.050  12.2
# 78.9                  10.300  10.3
# 79.0                  10.400  10.4
# 79.2                   9.900   9.9
# 79.4                   9.325  10.0
# 79.6                   9.400   9.4
# 79.7                  10.400  10.4
# 79.8                   9.700   9.7
# 80.1                   8.200   8.2
# 80.4                   6.400   6.4
# 80.7                   9.500   9.5
# 80.8                   7.900   7.9
# 81.1                   8.800   8.8
# 81.6                   7.500   7.5
# 81.7                   6.300   6.3
#
# [33 rows x 24 columns]

# %%
df_EUpop.head()
# Out:
#     country_name Continent          region   capital    area  population  \
# 0        Austria    Europe  Western Europe    Vienna   83879     8917000
# 1        Belgium    Europe  Western Europe  Brussels   30530    11544000
# 2         France    Europe  Western Europe     Paris  549087    67380000
# 3        Germany    Europe  Western Europe    Berlin  357580    83161000
# 4  Liechtenstein    Europe  Western Europe     Vaduz     161       38137
#
#    male_life_expectancy  female_life_expectancy  birth_rate  death_rate  \
# 0                  78.9                    83.6         9.4        10.3
# 1                  78.6                    83.1         9.9        11.0
# 2                  79.2                    85.3        10.9         9.9
# 3                  78.6                    83.4         9.3        11.9
# 4                  80.1                    83.6         9.1         8.2
#
#    pop_density
# 0        106.3
# 1        378.1
# 2        122.7
# 3        232.6
# 4        236.9

# %% [markdown]
# # EC 2
#
# ## Create only one histogram for the following two coloumns `male_life_expectancy` and `female_life_expectancy`. Make sure the bins are representative, i.e., make sure you select the appropriate value for the min and max based on the min and max of the two coloumns. Additionally, make sure the x label says `life expectancy` with a font size of 20, y label says `count` with fontsize 20 and all the tick sizes are with fontsize 30. Additionally, make sure that the two coloumns are in different colours.

# %%
# getting the min and max for male and female life expentancy
print(df_EUpop['male_life_expectancy'].min())

print(df_EUpop['male_life_expectancy'].max())
print(df_EUpop['female_life_expectancy'].max())
print(df_EUpop['female_life_expectancy'].min())
# Out:
# 66.4
# 81.7
# 85.3
# 76.2

# %%
# Put your code here:

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

# uses seaborn to adjust font size; sometimes not necessary, but 1.2 is a good default
# sns.set(font_scale=1.2)

# set the bins based on the range of the feature of interest So here these values are for the min and max rates of the male_life_expentancy.
bins = np.linspace(65, 87, 9)

# use matplotlib to make the histogram
plt.hist(df_EUpop['male_life_expectancy'], color='r',bins=bins)
plt.hist(df_EUpop['female_life_expectancy'], color='b',bins=bins)

plt.xlabel('life expectancy',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14., 16.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2.0, '2'),
#   Text(0, 4.0, '4'),
#   Text(0, 6.0, '6'),
#   Text(0, 8.0, '8'),
#   Text(0, 10.0, '10'),
#   Text(0, 12.0, '12'),
#   Text(0, 14.0, '14'),
#   Text(0, 16.0, '16')])
